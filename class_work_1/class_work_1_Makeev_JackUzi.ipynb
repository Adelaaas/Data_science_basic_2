# %%
arr = ['j', 'e', 'n', 'y', 'a', 17]
arr[1:-1]
# Out:
# ['e', 'n', 'y']

# %%
arr = ['j', 'e', 'n', 'y', 'a', 17]
c = '11p'
arr.append(c)
arr
# Out:
# ['j', 'e', 'n', 'y', 'a', 17, '11p']

# %%
arr = ['j', 'e', 'n', 'y', 'a', 17]
c = '11p'
arr.append(c)
s = 'makeev'
arr += list(s)
arr
# Out:
# ['j', 'e', 'n', 'y', 'a', 17, '11p', 'm', 'a', 'k', 'e', 'e', 'v']
