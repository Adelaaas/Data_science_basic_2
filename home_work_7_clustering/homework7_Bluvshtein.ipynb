# %%
import pandas as pd

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-0b8a27d4-766e-450e-9275-d313564ebef2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b8a27d4-766e-450e-9275-d313564ebef2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv

# %%
df = pd.read_csv("data.csv", sep=',')
df.head(5)
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %%
print(df['Loaned From'].isna().sum()) #т.к в этом столбце большая чать данных неизвестна, я приняла решение удалить этот столбец
df=df.drop(['Loaned From'], axis=1)
# Out:
# 16943

# %%
print(df.columns)
print(df.dtypes)
print( 'пустые значения', df.isna().sum())
df=df.dropna(axis=0, how='any')
df.info
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause'],
#       dtype='object')
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 88, dtype: object
# пустые значения Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 88, dtype: int64
# <bound method DataFrame.info of        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 1               1   20801  ...       11.0         €127.1M
# 2               2  190871  ...       11.0         €228.1M
# 4               4  192985  ...       13.0         €196.4M
# 5               5  183277  ...        8.0         €172.1M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [14743 rows x 88 columns]>

# %%
from sklearn.cluster import KMeans
# %matplotlib inline
import matplotlib.pyplot as plt
X = df.loc[:,['Weak Foot',
       'Skill Moves',
       'Jersey Number', 'Crossing', 'Finishing', 'HeadingAccuracy',
       'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
       'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
       'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
       'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
       'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
       'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning']]
#Группируем игроков по их физ характеристика
SSE = [] # Сумма квадратов ошибок для каждого результата

for k in range(1,10):
    kmeans = KMeans(n_clusters = k) # построить кластер
    kmeans.fit(X)
    SSE.append(kmeans.inertia_)
 
plt.plot(range(1,10), SSE, marker='s');
plt.xlabel('k')
plt.ylabel('SSE');
plt.show()

# %%
#на мой взгляд, после 6 изменяется не очень сильно
kmeans = KMeans(n_clusters=6)
kmeans.fit(X)
Y_pred = kmeans.labels_
df['Group']=Y_pred
df.head(15)
# Out:
#     Unnamed: 0      ID               Name  ...  GKReflexes Release Clause Group
# 0            0  158023           L. Messi  ...         8.0        €226.5M     3
# 1            1   20801  Cristiano Ronaldo  ...        11.0        €127.1M     3
# 2            2  190871          Neymar Jr  ...        11.0        €228.1M     3
# 4            4  192985       K. De Bruyne  ...        13.0        €196.4M     5
# 5            5  183277          E. Hazard  ...         8.0        €172.1M     3
# 6            6  177003          L. Modrić  ...         9.0        €137.4M     5
# 7            7  176580          L. Suárez  ...        37.0          €164M     3
# 8            8  155862       Sergio Ramos  ...        11.0        €104.6M     5
# 10          10  188545     R. Lewandowski  ...        10.0        €127.1M     3
# 11          11  182521           T. Kroos  ...        10.0        €156.8M     5
# 12          12  182493           D. Godín  ...        15.0         €90.2M     4
# 13          13  168542        David Silva  ...        12.0          €111M     3
# 14          14  215914           N. Kanté  ...        10.0        €121.3M     5
# 15          15  211110          P. Dybala  ...         8.0        €153.5M     3
# 16          16  202126            H. Kane  ...        11.0        €160.7M     3
#
# [15 rows x 89 columns]

# %%
x=df.loc[:,['Potential', 'Overall']]
SSE = [] # Сумма квадратов ошибок для каждого результата

for k in range(1,10):
    kmeans = KMeans(n_clusters = k) # построить кластер
    kmeans.fit(x)
    SSE.append(kmeans.inertia_)
 
plt.plot(range(1,10), SSE, marker='s');
plt.xlabel('k')
plt.ylabel('SSE');
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(x)
Y_pred = kmeans.labels_
x['cluster']=Y_pred

# %%
# X[строки, столбцы]
plt.plot(x[x['cluster']==0]['Overall'], x[x['cluster']==0]['Potential'], 'bo', label='class1')

plt.plot(x[x['cluster']==1]['Overall'], x[x['cluster']==1]['Potential'], 'go', label='class2')

plt.plot(x[x['cluster']==2]['Overall'], x[x['cluster']==2]['Potential'], 'ro', label='class3')

plt.plot(x[x['cluster']==3]['Overall'], x[x['cluster']==3]['Potential'], 'yo', label='class4')

plt.plot(x[x['cluster']==4]['Overall'], x[x['cluster']==4]['Potential'], 'co', label='class5')


plt.xlabel('Overall')
plt.ylabel('Potential')
plt.legend(loc=0)
plt.show()
