# %% [markdown]
# # Вариант 1.

# %% [markdown]
# Датасет: https://www.kaggle.com/karangadiya/fifa19

# %% [markdown]
# Ваша задача применив кластеризацию сгруппировать похожих игроков в кластеры.
#
# Задание:
# 1. Загрузить датасет в DataFrame
# 2. Исследуйте данные:
#     - размерность данных
#     - типы переменных в данных
#     - есть ли пропуски в данных? если да, то удалите их
# 3. Выберете переменные которые решили взять в качестве признаков для кластеризации. Объясните почему именно эти признаки взяли для кластеризации
# 4. Подберите число кластеров с помощью метода локтя, график визуалиции обязательно приведите. Объясните почему взяли именно это число кластеров.
# 5. Разбейте игроков на кластеры с помощью метода kmeans и создайте в датасете новую колонку в которую запишете кластер, в который попал ваш игрок. Сделайте вывод чем похожи игроки внутри класеров или по какому принципу организовались данные кластеры.
# 6. Выберете любые два признака и проведите по ним кластеризацию, визуализируйте полученные кластеры (берем всего 2 признака, чтобы была возможность визуализации кластеров в двумерном пространстве).

# %% [markdown]
# # Вариант 2

# %% [markdown]
# Датасет: https://www.kaggle.com/akram24/wine-pca

# %% [markdown]
# Ваша задача применив кластеризацию сгруппировать похожих игроков в кластеры.
#
# Задание:
# 1. Загрузить датасет в DataFrame
# 2. Исследуйте данные:
#     - размерность данных
#     - типы переменных в данных
#     - есть ли пропуски в данных? если да, то удалите их
# 3. Выберете переменные которые решили взять в качестве признаков для кластеризации. Объясните почему именно эти признаки взяли для кластеризации
# 4. Подберите число кластеров с помощью метода локтя, график визуалиции обязательно приведите. Объясните почему взяли именно это число кластеров.
# 5. Разбейте объекты на кластеры с помощью метода kmeans и создайте в датасете новую колонку в которую запишете кластер, в который попал ваш игрок. Сделайте вывод чем похожи игроки внутри класеров или по какому принципу организовались данные кластеры.
# 6. Выберете любые два признака и проведите по ним кластеризацию, визуализируйте полученные кластеры (берем всего 2 признака, чтобы была возможность визуализации кластеров в двумерном пространстве).

# %% [markdown]
# # Вариант 3

# %% [markdown]
# Датасет: https://www.kaggle.com/arjunbhasin2013/ccdata/tasks

# %% [markdown]
# Ваша задача применив кластеризацию сгруппировать похожих игроков в кластеры.
#
# Задание:
# 1. Загрузить датасет в DataFrame
# 2. Исследуйте данные:
#     - размерность данных
#     - типы переменных в данных
#     - есть ли пропуски в данных? если да, то удалите их
# 3. Выберете переменные которые решили взять в качестве признаков для кластеризации. Объясните почему именно эти признаки взяли для кластеризации
# 4. Подберите число кластеров с помощью метода локтя, график визуалиции обязательно приведите. Объясните почему взяли именно это число кластеров.
# 5. Разбейте объекты на кластеры с помощью метода kmeans и создайте в датасете новую колонку в которую запишете кластер, в который попал ваш игрок. Сделайте вывод чем похожи игроки внутри класеров или по какому принципу организовались данные кластеры.
# 6. Выберете любые два признака и проведите по ним кластеризацию, визуализируйте полученные кластеры (берем всего 2 признака, чтобы была возможность визуализации кластеров в двумерном пространстве).

# %% [markdown]
# # Вариант 4

# %% [markdown]
# Датасет: https://www.kaggle.com/ankitverma2010/clustering-engineering-college-data

# %% [markdown]
# Ваша задача применив кластеризацию сгруппировать похожих игроков в кластеры.
#
# Задание:
# 1. Загрузить датасет в DataFrame
# 2. Исследуйте данные:
#     - размерность данных
#     - типы переменных в данных
#     - есть ли пропуски в данных? если да, то удалите их
# 3. Выберете переменные которые решили взять в качестве признаков для кластеризации. Объясните почему именно эти признаки взяли для кластеризации
# 4. Подберите число кластеров с помощью метода локтя, график визуалиции обязательно приведите. Объясните почему взяли именно это число кластеров.
# 5. Разбейте объекты на кластеры с помощью метода kmeans и создайте в датасете новую колонку в которую запишете кластер, в который попал ваш игрок. Сделайте вывод чем похожи игроки внутри класеров или по какому принципу организовались данные кластеры.
# 6. Выберете любые два признака и проведите по ним кластеризацию, визуализируйте полученные кластеры (берем всего 2 признака, чтобы была возможность визуализации кластеров в двумерном пространстве).

# %% [markdown]
# # Вариант 5

# %% [markdown]
# Датасет: https://www.kaggle.com/iamhungundji/covid19-symptoms-checker
#
# Берете файл Cleaned-Data.csv

# %% [markdown]
# Ваша задача применив кластеризацию сгруппировать похожих игроков в кластеры.
#
# Задание:
# 1. Загрузить датасет в DataFrame
# 2. Исследуйте данные:
#     - размерность данных
#     - типы переменных в данных
#     - есть ли пропуски в данных? если да, то удалите их
# 3. Выберете переменные которые решили взять в качестве признаков для кластеризации. Объясните почему именно эти признаки взяли для кластеризации
# 4. Подберите число кластеров с помощью метода локтя, график визуалиции обязательно приведите. Объясните почему взяли именно это число кластеров.
# 5. Разбейте объекты на кластеры с помощью метода kmeans и создайте в датасете новую колонку в которую запишете кластер, в который попал ваш игрок. Сделайте вывод чем похожи игроки внутри класеров или по какому принципу организовались данные кластеры.
# 6. Выберете любые два признака и проведите по ним кластеризацию, визуализируйте полученные кластеры (берем всего 2 признака, чтобы была возможность визуализации кластеров в двумерном пространстве).
