# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b623641-3f2b-4ee0-a94e-793ae1dcd4da" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b623641-3f2b-4ee0-a94e-793ae1dcd4da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mushrooms.csv to mushrooms.csv

# %%
train = pd.read_csv("mushrooms.csv")

# %%
train.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
print(train.shape)
# Out:
# (8124, 23)

# %%
print(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
print(train.isna().sum())
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
from sklearn import preprocessing

# Создадим модель кодировщика
label_encoder = preprocessing.LabelEncoder() 
label_encoder1 = preprocessing.LabelEncoder() 
label_encoder2 = preprocessing.LabelEncoder() 
label_encoder3 = preprocessing.LabelEncoder()
label_encoder4 = preprocessing.LabelEncoder()
label_encoder5 = preprocessing.LabelEncoder()
label_encoder6 = preprocessing.LabelEncoder()
label_encoder7 = preprocessing.LabelEncoder()
label_encoder8 = preprocessing.LabelEncoder()
label_encoder9 = preprocessing.LabelEncoder()
label_encoder10 = preprocessing.LabelEncoder()
label_encoder11 = preprocessing.LabelEncoder()
label_encoder12 = preprocessing.LabelEncoder()
label_encoder13 = preprocessing.LabelEncoder()
label_encoder14 = preprocessing.LabelEncoder()
label_encoder15 = preprocessing.LabelEncoder()
label_encoder16 = preprocessing.LabelEncoder()
label_encoder17 = preprocessing.LabelEncoder()
label_encoder18 = preprocessing.LabelEncoder()
label_encoder19 = preprocessing.LabelEncoder()
label_encoder20 = preprocessing.LabelEncoder()
label_encoder21 = preprocessing.LabelEncoder()
label_encoder22 = preprocessing.LabelEncoder()

# Обучение кодировщика: по сути тут создает словарь уникальных слов из переданного массива, 
# соотносит для каждого слова число (все что делали выше мы, только тут автоматизированно)
label_encoder.fit(train['class']) 
label_encoder1.fit(train['cap-shape']) 
label_encoder2.fit(train['cap-surface']) 
label_encoder3.fit(train['cap-color']) 
label_encoder4.fit(train['bruises']) 
label_encoder5.fit(train['odor']) 
label_encoder6.fit(train['gill-attachment']) 
label_encoder7.fit(train['gill-spacing']) 
label_encoder8.fit(train['gill-size']) 
label_encoder9.fit(train['gill-color']) 
label_encoder10.fit(train['stalk-shape']) 
label_encoder11.fit(train['stalk-root']) 
label_encoder12.fit(train['stalk-surface-above-ring']) 
label_encoder13.fit(train['stalk-surface-below-ring']) 
label_encoder14.fit(train['stalk-color-above-ring']) 
label_encoder15.fit(train['stalk-color-below-ring']) 
label_encoder16.fit(train['veil-type']) 
label_encoder17.fit(train['veil-color']) 
label_encoder18.fit(train['ring-number']) 
label_encoder19.fit(train['ring-type']) 
label_encoder20.fit(train['spore-print-color']) 
label_encoder21.fit(train['population']) 
label_encoder22.fit(train['habitat']) 

# на этом этапе по сути применяет полученный словарь в переданным данных (в данном случае мы передали столбец lunch)
train['class'] = label_encoder.transform(train['class']) 
train['cap-shape'] = label_encoder1.transform(train['cap-shape']) 
train['cap-surface'] = label_encoder2.transform(train['cap-surface']) 
train['cap-color'] = label_encoder3.transform(train['cap-color']) 
train['bruises'] = label_encoder4.transform(train['bruises']) 
train['odor'] = label_encoder5.transform(train['odor']) 
train['gill-attachment'] = label_encoder6.transform(train['gill-attachment']) 
train['gill-spacing'] = label_encoder7.transform(train['gill-spacing']) 
train['gill-size'] = label_encoder8.transform(train['gill-size']) 
train['gill-color'] = label_encoder9.transform(train['gill-color']) 
train['stalk-shape'] = label_encoder10.transform(train['stalk-shape']) 
train['stalk-root'] = label_encoder11.transform(train['stalk-root']) 
train['stalk-surface-above-ring'] = label_encoder12.transform(train['stalk-surface-above-ring']) 
train['stalk-surface-below-ring'] = label_encoder13.transform(train['stalk-surface-below-ring']) 
train['stalk-color-above-ring'] = label_encoder14.transform(train['stalk-color-above-ring']) 
train['stalk-color-below-ring'] = label_encoder15.transform(train['stalk-color-below-ring']) 
train['veil-type'] = label_encoder16.transform(train['veil-type']) 
train['veil-color'] = label_encoder17.transform(train['veil-color']) 
train['ring-number'] = label_encoder18.transform(train['ring-number']) 
train['ring-type'] = label_encoder19.transform(train['ring-type']) 
train['spore-print-color'] = label_encoder20.transform(train['spore-print-color']) 
train['population'] = label_encoder21.transform(train['population']) 
train['habitat'] = label_encoder22.transform(train['habitat'])

train
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
train['class'].value_counts()
# Out:
# 0    4208
# 1    3916
# Name: class, dtype: int64

# %%
features = pd.Series(['cap-shape','cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat'])
from sklearn.linear_model import LinearRegression
X = train[['cap-shape','cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']].values

y = train['class'].values
slr = LinearRegression() 
slr.fit(X, y)
coeff_df = pd.DataFrame(slr.coef_, columns=['Coefficient'])  
coeff_df['features'] = features

coeff_df
# Out:
#      Coefficient                  features
# 0  -1.782007e-03                 cap-shape
# 1   2.334921e-02               cap-surface
# 2  -1.350020e-03                 cap-color
# 3  -3.485432e-01                   bruises
# 4  -2.248612e-02                      odor
# 5  -6.892356e-02           gill-attachment
# 6  -4.741419e-01              gill-spacing
# 7   5.390861e-01                 gill-size
# 8  -1.006871e-02                gill-color
# 9  -5.257538e-02               stalk-shape
# 10 -7.172193e-02                stalk-root
# 11 -1.611881e-01  stalk-surface-above-ring
# 12 -5.713523e-02  stalk-surface-below-ring
# 13 -1.098106e-02    stalk-color-above-ring
# 14 -6.321726e-03    stalk-color-below-ring
# 15 -1.665335e-16                 veil-type
# 16  4.007848e-01                veil-color
# 17  3.866249e-02               ring-number
# 18  1.783017e-02                 ring-type
# 19 -4.849111e-02         spore-print-color
# 20 -9.910442e-03                population
# ...

# %%
slr.intercept_
# Out:
# 0.585510501978783

# %% [markdown]
# y = ax + b

# %% [markdown]
# b = 0.585510501978783

# %%
from sklearn.model_selection import train_test_split

# train - на тренировочные и тестовые
X = train.drop(['class'], axis=1)
y = train['class']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3)

model = LogisticRegression()
# model = KMeans()
# model = LinearRegression()

# модель учится, для этого ей нужны правильные
model.fit(X_train, y_train)

# тестируем, для признаков у которых нет ответов, мы предсказывает ответ
answers_pred = model.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
from sklearn.metrics import accuracy_score
# Как оценить насколько хорошо работает ваша модель?
# answers_pred - ответы которые вернула модель для X_test
# y_test - это правильные ответы для X_test
print(accuracy_score(y_test,answers_pred))
# Out:
# 0.9581624282198523

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (5686, 22)
# (5686,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (2438, 22)
# (2438,)

# %%
predictions = model.predict(X)
predictions
# Out:
# array([1, 0, 0, ..., 0, 1, 0])
