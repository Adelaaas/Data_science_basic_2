# %%
name = "Komap"
print ('Текст', name, 'Текст')
# Out:
# Текст Komap Текст

# %%
Lst = ['a', 'ky', '499']
List = ['S', 'e', 'r', 'g', 'e', 'y']
print ('arr:', List )
print (List[0:7:1])
print (List[0:7])
print (Lst[0:7:1])
print (Lst[0:7])\
# Out:
# arr: ['S', 'e', 'r', 'g', 'e', 'y']
# ['S', 'e', 'r', 'g', 'e', 'y']
# ['S', 'e', 'r', 'g', 'e', 'y']
# ['a', 'ky', '499']
# ['a', 'ky', '499']

# %%
Listick = ['S', 'e', 'r', 'g', 'e', 'y', 18]
Class = "11I2"
username = 'Kushnir'
print (Listick [0:7])
Listick.append(Class)
print (Listick)
for i in username:
    Listick.append(i)
print(Listick)
# Out:
# ['S', 'e', 'r', 'g', 'e', 'y', 18]
# ['S', 'e', 'r', 'g', 'e', 'y', 18, '11I2']
# ['S', 'e', 'r', 'g', 'e', 'y', 18, '11I2', 'K', 'u', 's', 'h', 'n', 'i', 'r']
