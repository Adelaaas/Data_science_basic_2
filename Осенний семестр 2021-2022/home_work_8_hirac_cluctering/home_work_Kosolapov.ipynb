# %% [markdown]
# Вариант 3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e34203d0-25cf-4fa1-bb82-6ed17bf62add" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e34203d0-25cf-4fa1-bb82-6ed17bf62add">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CC GENERAL.csv to CC GENERAL.csv

# %%
import pandas as pd
df = pd.read_csv('CC GENERAL.csv')
df
# Out:
#      CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 0     C10001    40.900749  ...          0.000000      12
# 1     C10002  3202.467416  ...          0.222222      12
# 2     C10003  2495.148862  ...          0.000000      12
# 3     C10004  1666.670542  ...          0.000000      12
# 4     C10005   817.714335  ...          0.000000      12
# ...      ...          ...  ...               ...     ...
# 8945  C19186    28.493517  ...          0.500000       6
# 8946  C19187    19.183215  ...          0.000000       6
# 8947  C19188    23.398673  ...          0.250000       6
# 8948  C19189    13.457564  ...          0.250000       6
# 8949  C19190   372.708075  ...          0.000000       6
#
# [8950 rows x 18 columns]

# %%
print("Размерность данных",df.shape)
print(df.dtypes)
df = df.dropna(axis=0, how='any')
# Out:
# Размерность данных (8950, 18)
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
df.head(15)
# Out:
#    CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 0   C10001    40.900749  ...          0.000000      12
# 1   C10002  3202.467416  ...          0.222222      12
# 2   C10003  2495.148862  ...          0.000000      12
# 4   C10005   817.714335  ...          0.000000      12
# 5   C10006  1809.828751  ...          0.000000      12
# 6   C10007   627.260806  ...          1.000000      12
# 7   C10008  1823.652743  ...          0.000000      12
# 8   C10009  1014.926473  ...          0.000000      12
# 9   C10010   152.225975  ...          0.000000      12
# 10  C10011  1293.124939  ...          0.000000      12
# 11  C10012   630.794744  ...          0.000000      12
# 12  C10013  1516.928620  ...          0.250000      12
# 13  C10014   921.693369  ...          0.083333      12
# 14  C10015  2772.772734  ...          0.000000      12
# 15  C10016  6886.213231  ...          0.000000      12
#
# [15 rows x 18 columns]

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
#balance - баланс пользователя на карте
#purchases - общая сумма покупок
#purchase_trx - кол-во покупок

'''
таким образом можно отсортировать пользвателей на группы кто больше всего тратит и кто меньше

# %%
X = df.loc[:,['BALANCE','PURCHASES', 'PURCHASES_TRX']]

SSE = [] 

for k in range(1,15):
    kmeans = KMeans(n_clusters = k) 
    kmeans.fit(X)
    SSE.append(kmeans.inertia_)
 
plt.plot(range(1,15), SSE, marker='s');
plt.xlabel('k')
plt.ylabel('SSE');
plt.show()

# %%
# возьмем 9 кластеров, так как после него изменения незначительны

# %%
kmeans = KMeans(n_clusters=9)
kmeans.fit(X)
Y_pred = kmeans.labels_

df['CLASTER'] = Y_pred
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT  TENURE  CLASTER
# 0   C10001    40.900749           0.818182  ...          0.000000      12        0
# 1   C10002  3202.467416           0.909091  ...          0.222222      12        3
# 2   C10003  2495.148862           1.000000  ...          0.000000      12        3
# 4   C10005   817.714335           1.000000  ...          0.000000      12        0
# 5   C10006  1809.828751           1.000000  ...          0.000000      12        3
# 6   C10007   627.260806           1.000000  ...          1.000000      12        5
# 7   C10008  1823.652743           1.000000  ...          0.000000      12        3
# 8   C10009  1014.926473           1.000000  ...          0.000000      12        0
# 9   C10010   152.225975           0.545455  ...          0.000000      12        6
# 10  C10011  1293.124939           1.000000  ...          0.000000      12        3
# ...

# %%
X = df.loc[:,['BALANCE','PURCHASES', 'PURCHASES_TRX', 'CLASTER']]
X.head(50)
# Out:
#          BALANCE  PURCHASES  PURCHASES_TRX  CLASTER
# 0      40.900749      95.40              2        0
# 1    3202.467416       0.00              0        3
# 2    2495.148862     773.17             12        3
# 4     817.714335      16.00              1        0
# 5    1809.828751    1333.28              8        3
# 6     627.260806    7091.01             64        5
# 7    1823.652743     436.20             12        3
# 8    1014.926473     861.49              5        0
# 9     152.225975    1281.60              3        6
# 10   1293.124939     920.12             12        3
# 11    630.794744    1492.18              6        6
# 12   1516.928620    3217.99             26        5
# 13    921.693369    2137.93             26        6
# 14   2772.772734       0.00              0        3
# 15   6886.213231    1611.70             11        2
# 16   2072.074354       0.00              0        3
# 17     41.089489     519.00              8        0
# ...

# %%
'''
Игроки внутри кластеров похожи по значению столбца balance и соотношением столбцов balance и purchases
'''

# %%
X = df.loc[:,['ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY']]
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
Y_pred = kmeans.labels_
df['sclaster'] = Y_pred
df.head(20)
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT  TENURE  sclaster
# 0   C10001    40.900749           0.818182  ...          0.000000      12         0
# 1   C10002  3202.467416           0.909091  ...          0.222222      12         0
# 2   C10003  2495.148862           1.000000  ...          0.000000      12         0
# 3   C10004  1666.670542           0.636364  ...          0.000000      12         0
# 4   C10005   817.714335           1.000000  ...          0.000000      12         0
# 5   C10006  1809.828751           1.000000  ...          0.000000      12         1
# 6   C10007   627.260806           1.000000  ...          1.000000      12         1
# 7   C10008  1823.652743           1.000000  ...          0.000000      12         1
# 8   C10009  1014.926473           1.000000  ...          0.000000      12         0
# 9   C10010   152.225975           0.545455  ...          0.000000      12         0
# ...

# %%
X = df.loc[:,['ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY', 'sclaster']]

# %%
plt.plot(X[X['sclaster']==0]['ONEOFF_PURCHASES_FREQUENCY'], X[X['sclaster']==0]['PURCHASES_INSTALLMENTS_FREQUENCY'], 'bo', label='class1')
plt.plot(X[X['sclaster']==1]['ONEOFF_PURCHASES_FREQUENCY'], X[X['sclaster']==1]['PURCHASES_INSTALLMENTS_FREQUENCY'], 'go', label='class2')

plt.xlabel('ONEOFF_PURCHASES_FREQUENCY')
plt.ylabel('PURCHASES_INSTALLMENTS_FREQUENCY')
plt.legend(loc=0)
plt.show()

# %%
#----------------------------

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.cluster import AgglomerativeClustering
from matplotlib import pyplot as plt

import numpy as np

# %%
X = df.loc[:,['BALANCE','PURCHASES', 'PURCHASES_TRX']]
#Z = linkage(X, 'ward')

Z = linkage(X, 'ward')

fig = plt.figure(figsize=(10, 10))
dn = dendrogram(Z)

# %%
hc = AgglomerativeClustering(n_clusters =9, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(X)
y_hc
# Out:
# array([6, 8, 4, ..., 6, 6, 6])

# %%
print(y_hc[:100])
df['pred_sclearn'] = y_hc
# Out:
# [6 8 4 4 0 0 4 4 6 4 6 3 0 4 1 4 6 4 8 4 3 6 3 8 6 4 6 1 6 1 0 1 6 8 4 1 3
#  1 4 6 6 8 4 8 6 0 4 8 0 4 0 0 8 8 4 4 4 0 4 4 4 8 0 8 3 6 4 6 8 4 4 4 1 6
#  6 6 6 0 6 1 1 8 8 7 4 4 4 4 6 6 6 3 4 4 6 8 4 3 6 3]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      CUST_ID      BALANCE  ...  TENURE  pred_sclearn
# 0     C10001    40.900749  ...      12             6
# 1     C10002  3202.467416  ...      12             8
# 2     C10003  2495.148862  ...      12             4
# 4     C10005   817.714335  ...      12             4
# 5     C10006  1809.828751  ...      12             0
# ...

# %%
plt.scatter(X.loc[y_hc==0, 'BALANCE'], X.loc[y_hc==0, 'PURCHASES'], s=50, marker='o', color='red')
plt.scatter(X.loc[y_hc==1, 'BALANCE'], X.loc[y_hc==1, 'PURCHASES'], s=50, marker='o', color='blue')
plt.scatter(X.loc[y_hc==2, 'BALANCE'], X.loc[y_hc==2, 'PURCHASES'], s=50, marker='o', color='green')
plt.scatter(X.loc[y_hc==3, 'BALANCE'], X.loc[y_hc==3, 'PURCHASES'], s=50, marker='o', color='orange')
plt.scatter(X.loc[y_hc==4, 'BALANCE'], X.loc[y_hc==4, 'PURCHASES'], s=50, marker='o', color='black')
plt.scatter(X.loc[y_hc==5, 'BALANCE'], X.loc[y_hc==5, 'PURCHASES'], s=50, marker='o', color='pink')
plt.scatter(X.loc[y_hc==6, 'BALANCE'], X.loc[y_hc==6, 'PURCHASES'], s=50, marker='o', color='gray')
plt.scatter(X.loc[y_hc==7, 'BALANCE'], X.loc[y_hc==7, 'PURCHASES'], s=50, marker='o', color='purple')
plt.scatter(X.loc[y_hc==8, 'BALANCE'], X.loc[y_hc==8, 'PURCHASES'], s=50, marker='o', color='darkblue')
