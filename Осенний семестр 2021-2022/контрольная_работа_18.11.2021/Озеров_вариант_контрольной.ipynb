# %% [markdown]
# # Озеров Андрей Владимирович
#
# Ссылка на данные: https://www.kaggle.com/lodetomasi1995/income-classification

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a01331a4-ec5b-481f-88df-21b6e16582ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a01331a4-ec5b-481f-88df-21b6e16582ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving income_evaluation.csv to income_evaluation.csv

# %%
# 1. Считайте DataFrame

# ваш код тут

# %%
import pandas as pd

df = pd.read_csv('income_evaluation.csv')
df.head()
# Out:
#    age          workclass   fnlwgt  ...  hours-per-week   native-country  income
# 0   39          State-gov    77516  ...              40    United-States   <=50K
# 1   50   Self-emp-not-inc    83311  ...              13    United-States   <=50K
# 2   38            Private   215646  ...              40    United-States   <=50K
# 3   53            Private   234721  ...              40    United-States   <=50K
# 4   28            Private   338409  ...              40             Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
# 2. Проведите анализ DataFrame
# - Какая размерность данных?
# - Какие типы переменных представленны в наборе данных?
# - Есть пропуски в данных? Если да, удалите строки, в которых есть пропуски

# ваш код тут

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1    workclass       32561 non-null  object
#  2    fnlwgt          32561 non-null  int64
#  3    education       32561 non-null  object
#  4    education-num   32561 non-null  int64
#  5    marital-status  32561 non-null  object
#  6    occupation      32561 non-null  object
#  7    relationship    32561 non-null  object
#  8    race            32561 non-null  object
#  9    sex             32561 non-null  object
#  10   capital-gain    32561 non-null  int64
#  11   capital-loss    32561 non-null  int64
#  12   hours-per-week  32561 non-null  int64
#  13   native-country  32561 non-null  object
#  14   income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isna()
# Out:
#          age   workclass   fnlwgt  ...   hours-per-week   native-country   income
# 0      False       False    False  ...            False            False    False
# 1      False       False    False  ...            False            False    False
# 2      False       False    False  ...            False            False    False
# 3      False       False    False  ...            False            False    False
# 4      False       False    False  ...            False            False    False
# ...      ...         ...      ...  ...              ...              ...      ...
# 32556  False       False    False  ...            False            False    False
# 32557  False       False    False  ...            False            False    False
# 32558  False       False    False  ...            False            False    False
# 32559  False       False    False  ...            False            False    False
# ...

# %%
df.dropna(axis=0, how='any')
# Out:
#        age          workclass   fnlwgt  ...  hours-per-week   native-country  income
# 0       39          State-gov    77516  ...              40    United-States   <=50K
# 1       50   Self-emp-not-inc    83311  ...              13    United-States   <=50K
# 2       38            Private   215646  ...              40    United-States   <=50K
# 3       53            Private   234721  ...              40    United-States   <=50K
# 4       28            Private   338409  ...              40             Cuba   <=50K
# ...    ...                ...      ...  ...             ...              ...     ...
# 32556   27            Private   257302  ...              38    United-States   <=50K
# 32557   40            Private   154374  ...              40    United-States    >50K
# 32558   58            Private   151910  ...              40    United-States   <=50K
# 32559   22            Private   201490  ...              20    United-States   <=50K
# ...

# %%
# 3. Написать фукнцию, которая принимает DataFrame
# и возвращает кортеж (среднее значение возраста для income <=50K, среднее значение возраста для income >50)

# ваш код тут

# %%
# 4. Построить график:
# - гистограмма распределения количества людей для каждого типа race
# графики располагаются на разных координатных плоскостях
# У графика должен быть заголовок, подписаны оси, а также легенда (т е графики должны быть подписаны)

# ваш код тут

# %%
import matplotlib.pyplot as plt

x = ['White', 'Black']
y = [len(df[df[' race'] == ' White']), len(df[df[' race'] == ' Black'])]

fig, ax = plt.subplots()
ax.bar(x, y)
plt.title('Распределение типа race')
plt.show()

# %%
# 6. Посчитайте количество уникальных значений в столбце education
# Удалите пробелы из строк в этом столбце
# Посчитайте среднее значение возраста для Bachelors, у которых sex = Male

# ваш код тут

# %%
df = df[' education'].replace(' ', '')
df
# Out:
# 0          Bachelors
# 1          Bachelors
# 2            HS-grad
# 3               11th
# 4          Bachelors
#             ...
# 32556     Assoc-acdm
# 32557        HS-grad
# 32558        HS-grad
# 32559        HS-grad
# 32560        HS-grad
# Name:  education, Length: 32561, dtype: object

# %%
df[' education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name:  education, dtype: int64

# %%
# 5. Замените все уникальные значения в столбце education на числовые
# например,'Bachelors' на 0

# ваш код тут

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
df[' education'] = labelencoder.fit_transform(df[' education'])
df
# Out:
#        age          workclass   fnlwgt  ...   hours-per-week   native-country  income
# 0       39          State-gov    77516  ...               40    United-States   <=50K
# 1       50   Self-emp-not-inc    83311  ...               13    United-States   <=50K
# 2       38            Private   215646  ...               40    United-States   <=50K
# 3       53            Private   234721  ...               40    United-States   <=50K
# 4       28            Private   338409  ...               40             Cuba   <=50K
# ...    ...                ...      ...  ...              ...              ...     ...
# 32556   27            Private   257302  ...               38    United-States   <=50K
# 32557   40            Private   154374  ...               40    United-States    >50K
# 32558   58            Private   151910  ...               40    United-States   <=50K
# 32559   22            Private   201490  ...               20    United-States   <=50K
# ...
