# %% [markdown]
# # Блувштейн Елизавета Евгеньевна
#
# Ссылка на данные: https://www.kaggle.com/prathamtripathi/drug-classification

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-b42df105-3093-41c4-8049-f13f4d7a1147" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b42df105-3093-41c4-8049-f13f4d7a1147">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving drug200.csv to drug200 (3).csv

# %%
import pandas as pd
df = pd.read_csv("drug200.csv", sep=',')
df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  DrugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  DrugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
# 2. Написать фукнцию, которая принимает DataFrame
# и возвращает кортеж (максимальный возраст, среднее значения возраста) для всех мужчин
def age(df):
  df1=df[df['Sex']=='M']
  average=df1['Age'].mean()
  max=df1['Age'].max()
  return average, max
age(df)
df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  DrugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  DrugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
# 3. Построить два точечных графика на разных кординатных плоскостях (они должны быть по горизонтали)
# График зависимости возраста от переменной Drug
# График зависимости Na_to_K от переменной Drug
# У графика должен быть заголовок, подписаны оси, а также легенда (т е графики должны быть подписаны)
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mtcars.csv") # обратите внимание, pandas способен считывать данные из файла по ссылке




import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-dce2fdf31297> in <module>()
#       9
#      10 import matplotlib.pyplot as plt
# ---> 11 df.plt(x = 'Age',y = 'Drug', kind='scatter')
#      12 plt.title('Распределение возраста в зависимости от drug')
#      13 plt.xlabel("Age")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'plt'

# %%
# 4. Проведите анализ DataFrame
# - Какая размерность данных?
# - Какие типы переменных представленны в наборе данных?
# - Есть пропуски в данных? Если да, удалите строки, в которых есть пропуски
print(df.info())
print('-'*10)
print(df.dtypes)
print('-'*10)
print(df.isna().sum(), "значение None")
print('-'*10)
df.dropna(axis=0, how='all')
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB
# None
# ----------
# Age              int64
# Sex             object
# BP              object
# Cholesterol     object
# Na_to_K        float64
# Drug            object
# dtype: object
# ----------
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64 значение None
# ----------
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  DrugY
# ...

# %%
# 5.Удалите из DataFrame с 10 по 50 строки

df.drop(df.index[11:50], inplace=True)
df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  DrugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  DrugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [161 rows x 6 columns]

# %%
# 6. Создайте новый столбец в DataFrame, в котором будет среднее значение столбца возраста для каждого типа Drug
# Пример вывода приведен
df.loc[:, 'Drug']
