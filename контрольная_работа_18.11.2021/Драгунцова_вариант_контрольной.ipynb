# %% [markdown]
# # Драгунцова Инна Геннадьевна
#
# Ссылка на данные: https://www.kaggle.com/benroshan/factors-affecting-campus-placement

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3b9911b2-6cdc-47ca-ab02-8c70465eddca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b9911b2-6cdc-47ca-ab02-8c70465eddca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Placement_Data_Full_Class.csv to Placement_Data_Full_Class.csv

# %%
# 1. Считайте DataFrame
# ваш код тут
import pandas as pd
df = pd.read_csv("Placement_Data_Full_Class.csv", sep=",")
df
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0        1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1        2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2        3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3        4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       NaN
# 4        5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
# ..     ...    ...    ...      ...  ...             ...    ...         ...       ...
# 210    211      M  80.60   Others  ...         Mkt&Fin  74.49      Placed  400000.0
# 211    212      M  58.00   Others  ...         Mkt&Fin  53.62      Placed  275000.0
# 212    213      M  67.00   Others  ...         Mkt&Fin  69.72      Placed  295000.0
# 213    214      F  74.00   Others  ...          Mkt&HR  60.23      Placed  204000.0
# ...

# %%
# 2. Написать фукнцию, которая принимает DataFrame
# и возвращает количество строк для каждого типа 'gender',
# количество строк для каждого типа 'status'

def vsego_str(dfr, pr):
  return dfr[pr].value_counts()
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

df1 = vsego_str(df, 'gender')
print('Количество строк для каждого типа gender:')
print(df1)

print()

df2 = vsego_str(df, 'status')
print('Количество строк для каждого типа status:')
print(df2)
# ваш код тут
# Out:
# Количество строк для каждого типа gender:
# M    139
# F     76
# Name: gender, dtype: int64
#
# Количество строк для каждого типа status:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %%
# 3. Построить график:
# - гистограмма распределения количества записей для каждого типа 'gender'
# - гистограмма распределения количествазаписей для каждого типа 'hsc_s'
# Графики должны располагать на разных координатных плоскостях
# У графика должен быть заголовок, подписаны оси, а также легенда (т е графики должны быть подписаны)

df = pd.read_csv("Placement_Data_Full_Class.csv", sep=",")
df.head()


 
df['gender'].hist(legend=True)
df['hsc_s'].hist(legend=True, color="r")
# ваш код тут

# %%
# 4. Проведите анализ DataFrame
# - Какая размерность данных?
# - Какие типы переменных представленны в наборе данных?
# - Есть пропуски в данных? Если да, удалите строки, в которых есть пропуски

print("Размерность: ", df.shape)
print("Типы переменных: ")
print(df.dtypes)
df3 = df.isna().sum()
print("Количество пропусков:", df3.sum())
df = df.dropna(axis=0, how='any')
df

# ваш код тут
# Out:
# Размерность:  (148, 14)
# Типы переменных:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# salary            float64
# dtype: object
# Количество пропусков: 0
#         sl_no gender  ssc_p    ssc_b  ...  etest_p specialisation  mba_p    salary
# status                                ...
# Placed      1      M  67.00   Others  ...     55.0         Mkt&HR  58.80  270000.0
# Placed      2      M  79.33  Central  ...     86.5        Mkt&Fin  66.28  200000.0
# Placed      3      M  65.00  Central  ...     75.0        Mkt&Fin  57.80  250000.0
# Placed      5      M  85.80  Central  ...     96.8        Mkt&Fin  55.50  425000.0
# ...

# %%
# 5. Удалите все строки, в которых значение status == Placed
df.query('status != "Not Placed"')
print(df)
# ваш код тут
# Out:
#         sl_no gender  ssc_p    ssc_b  ...  etest_p specialisation  mba_p    salary
# status                                ...
# Placed      1      M  67.00   Others  ...     55.0         Mkt&HR  58.80  270000.0
# Placed      2      M  79.33  Central  ...     86.5        Mkt&Fin  66.28  200000.0
# Placed      3      M  65.00  Central  ...     75.0        Mkt&Fin  57.80  250000.0
# Placed      5      M  85.80  Central  ...     96.8        Mkt&Fin  55.50  425000.0
# Placed      8      M  82.00  Central  ...     67.0        Mkt&Fin  62.14  252000.0
# ...       ...    ...    ...      ...  ...      ...            ...    ...       ...
# Placed    210      M  62.00  Central  ...     67.0        Mkt&Fin  56.49  216000.0
# Placed    211      M  80.60   Others  ...     91.0        Mkt&Fin  74.49  400000.0
# Placed    212      M  58.00   Others  ...     74.0        Mkt&Fin  53.62  275000.0
# Placed    213      M  67.00   Others  ...     59.0        Mkt&Fin  69.72  295000.0
# ...

# %%
# 6. Создайте новый столбец в DataFrame, в котором будут типы Sex будут заменены на числовые значения
# например, все значения M станут равны 0, a F заменены на 1
df['Sex']
# ваш код тут
