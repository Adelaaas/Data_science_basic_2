# %% [markdown]
# # Кушнир Сергей Валентинович
#
# Ссылка на данные:https://www.kaggle.com/ishadss/productivity-prediction-of-garment-employees

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-41d01973-3af1-4614-973c-bcc42ccb597e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41d01973-3af1-4614-973c-bcc42ccb597e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving garments_worker_productivity.csv to garments_worker_productivity.csv

# %%
# 1. Считайте DataFrame
import pandas as pd

df=pd.read_csv("garments_worker_productivity.csv", sep=',')
df
# Out:
#            date   quarter  ... no_of_workers actual_productivity
# 0      1/1/2015  Quarter1  ...          59.0            0.940725
# 1      1/1/2015  Quarter1  ...           8.0            0.886500
# 2      1/1/2015  Quarter1  ...          30.5            0.800570
# 3      1/1/2015  Quarter1  ...          30.5            0.800570
# 4      1/1/2015  Quarter1  ...          56.0            0.800382
# ...         ...       ...  ...           ...                 ...
# 1192  3/11/2015  Quarter2  ...           8.0            0.628333
# 1193  3/11/2015  Quarter2  ...           8.0            0.625625
# 1194  3/11/2015  Quarter2  ...           8.0            0.625625
# 1195  3/11/2015  Quarter2  ...          15.0            0.505889
# 1196  3/11/2015  Quarter2  ...           6.0            0.394722
#
# [1197 rows x 15 columns]

# %%
# 2. Проведите анализ DataFrame
# - Какая размерность данных?
# - Какие типы переменных представленны в наборе данных?
# - Есть пропуски в данных? Если да, удалите строки, в которых есть пропуски

print('Размерность:',df.shape)
print('Типы:',df.dtypes)
print('Пропуски в данных:',df.isna().sum())

# Если бы были                
# df.dropna(axis=0, how='all')
# df
# Out:
# Размерность: (1197, 15)
# Типы: date                      object
# quarter                   object
# department                object
# day                       object
# team                       int64
# targeted_productivity    float64
# smv                      float64
# wip                      float64
# over_time                  int64
# incentive                  int64
# idle_time                float64
# idle_men                   int64
# no_of_style_change         int64
# no_of_workers            float64
# actual_productivity      float64
# dtype: object
# Пропуски в данных: date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# ...

# %%
# 3. Напишите функцию, которая принимает DataFrame
# и возвращает среднее значение actual_productivity для каждого типа day
df=pd.read_csv("garments_worker_productivity.csv", sep=',')
print(df['day'])
# ваш код тут
# Out:
# 0        Thursday
# 1        Thursday
# 2        Thursday
# 3        Thursday
# 4        Thursday
#           ...
# 1192    Wednesday
# 1193    Wednesday
# 1194    Wednesday
# 1195    Wednesday
# 1196    Wednesday
# Name: day, Length: 1197, dtype: object

# %%
# 4. Постройте график:
# - гистограмма количества строк для которых actual_productivity меньше среднего actual_productivity и кол-во строк больше среднего actual_productivity
# - гистограмма количества записей для каждого типа department

# Графики должны располагать на РАЗНЫХ координатных плоскостях
# У графика должен быть заголовок, подписаны оси, а также легенда (т е графики должны быть подписаны)

# ваш код тут

# %%
# 5. Удалите из набора данных все строки где, day = Thursday для которых team < 7

days = df[(df['day'] == 'Thursday')].index
correct = df[(df['team'] < 7)].index
pof=df
pof.drop(correct , inplace=True)
pof
# Out:
#            date   quarter  ... no_of_workers actual_productivity
# 0      1/1/2015  Quarter1  ...          59.0            0.940725
# 2      1/1/2015  Quarter1  ...          30.5            0.800570
# 3      1/1/2015  Quarter1  ...          30.5            0.800570
# 5      1/1/2015  Quarter1  ...          56.0            0.800125
# 10     1/1/2015  Quarter1  ...          57.5            0.721127
# ...         ...       ...  ...           ...                 ...
# 1191  3/11/2015  Quarter2  ...          57.0            0.650596
# 1192  3/11/2015  Quarter2  ...           8.0            0.628333
# 1193  3/11/2015  Quarter2  ...           8.0            0.625625
# 1194  3/11/2015  Quarter2  ...           8.0            0.625625
# 1195  3/11/2015  Quarter2  ...          15.0            0.505889
#
# [596 rows x 15 columns]

# %%
# 6. Создайте новый столбец в DataFrame, в котором будет записано среднее значение
# трех столбцов targeted_productivity, smv, wip

df['mean TSW'] = (df['targeted_productivity'] + df['smv'] + df['wip']) / 3
df
# Out:
#            date   quarter  ... actual_productivity    mean TSW
# 0      1/1/2015  Quarter1  ...            0.940725  378.320000
# 1      1/1/2015  Quarter1  ...            0.886500         NaN
# 2      1/1/2015  Quarter1  ...            0.800570  326.736667
# 3      1/1/2015  Quarter1  ...            0.800570  326.736667
# 4      1/1/2015  Quarter1  ...            0.800382  398.900000
# ...         ...       ...  ...                 ...         ...
# 1192  3/11/2015  Quarter2  ...            0.628333         NaN
# 1193  3/11/2015  Quarter2  ...            0.625625         NaN
# 1194  3/11/2015  Quarter2  ...            0.625625         NaN
# 1195  3/11/2015  Quarter2  ...            0.505889         NaN
# 1196  3/11/2015  Quarter2  ...            0.394722         NaN
#
# [1197 rows x 16 columns]
